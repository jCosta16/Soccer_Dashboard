# %%
# Dependencies
import requests
import os
from os.path  import basename
from bs4 import BeautifulSoup
import pandas as pd
from glob import glob
import datetime
from datetime import datetime
import time
from random import randint
import unicodedata

# %%
leagues_df = pd.read_csv("../data/leagues_data.csv")

# %%
leagues_df
# Out:
#    league_ID        country  tier      league_name  \
# 0          1         Brazil     1   Brazil Serie A
# 1          2  United States     1         MLS (US)
# 2          3         Mexico     1    Liga MX (MEX)
# 3          4      Argentina     1  Superliga (ARG)
#
#                                          league_link
# 0  https://www.transfermarkt.com/campeonato-brasi...
# 1  https://www.transfermarkt.com/major-league-soc...
# 2  https://www.transfermarkt.com/liga-mx-clausura...
# 3  https://www.transfermarkt.com/primera-division...

# %%
# to be able to scrape this website we need to use 'User Agents'
# more info about user agents in 'https://webscraping.com/blog/User-agents/'
# You can find your User-Agent at 'http://whatsmyuseragent.com/'
headers = {'User-Agent': 
           'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}

# %%
convert_url = "https://www.google.com/search?q=euro+to+dollar&oq=eur&aqs=chrome.1.69i57j35i39j0j46j0l2j69i61l2.2373j1j4&sourceid=chrome&ie=UTF-8"
html = requests.get(convert_url, headers=headers)
soup = BeautifulSoup(html.content, 'html.parser')
curr_value = soup.find('div', class_= "b1hJbf")
curr_value = round(float(curr_value["data-exchange-rate"]),2)

def get_value_us(x):
    value = []
    for char in x:
        value.append(char)
    if value[-1] == "m":
        float_value = "".join(value[1:-1])
        return round(float(float_value)*curr_value,2)
    else:
        float_value = "".join(value[1:-3])
        return round((float(float_value)*curr_value)/1000,2)

# %%
def strip_accents(text):

    try:
        text = unicode(text, 'utf-8')
    except NameError: # unicode is a default on python 3 
        pass

    text = unicodedata.normalize('NFD', text)\
           .encode('ascii', 'ignore')\
           .decode("utf-8")

    return str(text.strip())

# %%
def fix_heights(df):
    heights = []
    
    for index, row in df.iterrows():
        if pd.notnull(row["Height"]):
            heights.append(row["Height"])
        else:
            nat = row["Nat"]
            position = row["position"]
            field_position = row["field_position"]
            comp_players = df.loc[((df["Nat"] == nat) & (df["position"] == position))]
            avg_df = round(comp_players["Height"].mean(skipna = True),2)
            row["Height"] = avg_df
            if pd.isnull(row["Height"]):
                comp_players2 = df.loc[((df["Nat"] == nat) & (df["field_position"] == field_position))]
                avg_df2 = round(comp_players2["Height"].mean(skipna = True),2)
                row["Height"] = avg_df2
                if pd.isnull(row["Height"]):
                    comp_players3 = df.loc[((df["position"] == position))]
                    avg_df3 = round(comp_players3["Height"].mean(skipna = True),2)
                    row["Height"] = avg_df3
            heights.append(row["Height"])
    
    
    df.height = heights

# %%
def scrape_league_data(leagues_df):
    team_id = 1
    team_ID = []
    links = []
    names = []
    logos = []
    squads = []
    foreigners = []
    total_MVs = []
    avg_MVs = []
    league_ID = []
    
    for index, row in leagues_df.iterrows():
        url = row["league_link"]
        league_name = row["league_name"]
        tier = row["tier"]
        country = row["country"]
        league_id = row["league_ID"]
        time.sleep(1.1)
        print(f"scraping: {country}_{tier}_{league_name}")
        html = requests.get(url, headers=headers)
        soup = BeautifulSoup(html.content, 'html.parser')
        htmltable = soup.find('table', class_= "items")


        results = htmltable.findAll("tr", class_ =["odd","even"])


        for result in results:
            features = result.findAll("td")
            links.append(("https://www.transfermarkt.com"+result.find("a", href=True)\
                          ["href"]+"/plus/1").replace("startseite", "kader"))
            logo = result.find("img", src=True)["src"]
            logo = logo.split("?")[0]
            logo = logo.replace("tiny", "header")
            logos.append(logo)
            name = features[1].text
            names.append(strip_accents(name))
            squad = features[3].text
            squads.append(squad)
            foreigner = features[5].text
            foreigners.append(foreigner)
            total_MV = get_value_us(features[6].text)
            total_MVs.append(total_MV)
#             print(features[7])
            avg_MV = get_value_us(features[7].text)
            avg_MVs.append(avg_MV)
            team_ID.append(team_id)
            league_ID.append(league_id)
            team_id = team_id + 1

            
#         break


    # Create a Dataframe and export to a .csv file
    df = pd.DataFrame(list(zip(team_ID, league_ID, names, squads, foreigners,avg_MVs, total_MVs, logos,links)), \
columns =["team_ID", "league_ID","club","squad", "foreigners", "avg_market_value_m", "total_MV_m",'Logo_img', "link_page"]) 
    df['league_ID'] = df['league_ID'].astype(int)
    df['team_ID'] = df['team_ID'].astype(int)

    df.to_csv(f'../data/teams_trmk.csv',index=False)

# %%
def scrape_team_data(teams_df):
    player_id = 1
    name = []
    player_page = []
    position = []
    f_posi = []
    Age = []
    Nat = []
    Height = []
    foot = []
    dt_joined = []
    prev_team = []
    contract_expires = []
    market_value = []
    team_ID = []
    players_ID = []
    

    df_league = pd.read_csv(teams_df)
    for index, row in df_league.iterrows():
        team_id = row["team_ID"]
        team = row["link_page"]
        league_id = row["league_ID"]
        team_name = team.split('/')[-8]
        print(team_name)
        time.sleep(randint(1,2))
        html = requests.get(team, headers=headers)
        soup = BeautifulSoup(html.content, 'html.parser')
        htmltable = soup.find('table', class_= "items")

        results = htmltable.findAll("tr", class_ =["odd","even"])


        for result in results:
            features = result.findAll("td")

            name_1 = features[2].find("img", alt=True)["alt"]

            player_page.append("https://www.transfermarkt.com" + features[3].find("a", href=True)["href"])

            position_1 = features[4].text
            
            if position_1 in ("Centre-Back", "Left-Back", "Right-Back", "Defender"):
                field_posit = "DEF"
            elif position_1 in ("Defensive Midfield", "Central Midfield" , "Right Midfield" , "Left Midfield" , \
            "Attacking Midfield" , "Midfield"):
                field_posit = "MID"
            elif position_1 in ("Left Winger" , "Right Winger" , "Centre-Forward" , "Second Striker" , "Forward"):
                field_posit = "ATT"
            else:
                field_posit = "GLK"

            try:
                age_1 = int((features[5].text.split("(",)[-1])[:-1])
            except:
                age_1 = ""

            nat = features[6].img["alt"]
            
            if league_id == 3 or   league_id == 4:
                try:
                    Height_1 = float((features[8].text.split(" ")[0]).replace(",", "."))
                except:
                    Height_1 = ""

                foot_1 = features[9].text
                dt_joined_1 = features[10].text
                try:
                    dt_joined_1 = datetime.strptime(dt_joined_1, '%b %d, %Y').date()
                except:
                    dt_joined_1 = ""
                try:
                    prev_team_1 = features[11].img["alt"]
                except:
                    prev_team_1 = "N.A."

                contract_expires_1 = features[12].text
                try:
                    contract_expires_1 = datetime.strptime(contract_expires_1, '%d.%m.%Y').date()
                except:
                    contract_expires_1 = ""

                try:
                    market_value_1 = get_value_us(features[13].text[:-2])
                except:
                    market_value_1 = 0
            else:
                try:
                    Height_1 = float((features[7].text.split(" ")[0]).replace(",", "."))
                except:
                    Height_1 = ""

                foot_1 = features[8].text

                dt_joined_1 = features[9].text
                try:
                    dt_joined_1 = datetime.strptime(dt_joined_1, '%b %d, %Y').date()
                except:
                    dt_joined_1 = ""

                try:
                    prev_team_1 = features[10].img["alt"]
                except:
                    prev_team_1 = "N.A."


                contract_expires_1 = features[11].text
                try:
                    contract_expires_1 = datetime.strptime(contract_expires_1, '%d.%m.%Y').date()
                except:
                    contract_expires_1 = ""

                try:
                    market_value_1 = get_value_us(features[12].text[:-2])
                except:
                    market_value_1 = 0

            name.append(strip_accents(name_1))
            position.append(position_1)
            f_posi.append(field_posit)
            Age.append(age_1)
            Nat.append(nat)
            Height.append(Height_1)
            foot.append(foot_1)
            dt_joined.append(dt_joined_1)
            prev_team.append(strip_accents(prev_team_1))
            contract_expires.append(contract_expires_1)
            market_value.append(market_value_1)
            team_ID.append(team_id)
            players_ID.append(player_id)
            player_id = player_id+1

#         time.sleep(randint(3,5))
        

    df = pd.DataFrame(list(zip(players_ID, team_ID, name, position,f_posi, Age,Nat, Height, foot,dt_joined,prev_team, contract_expires,\
                               market_value,player_page)), 
                      columns =["players_ID", "team_ID","name","position","field_position", "Age", "Nat","Height","foot",'dt_joined',"prev_team", \
                                "contract_expires", "market_value","player_page" ])
    df['players_ID'] = df['players_ID'].astype(int)
    df['team_ID'] = df['team_ID'].astype(int)
    df['dt_joined'] = pd.to_datetime(df['dt_joined'])
    df['contract_expires'] = pd.to_datetime(df['contract_expires'])
    
    fix_heights(df)

    df.to_csv(f"../data/players_trmk.csv" ,index=False)

# %%
scrape_league_data(leagues_df)
# Out:
# scraping: Brazil_1_Brazil Serie A
# scraping: United States_1_MLS (US)
# scraping: Mexico_1_Liga MX (MEX)
# scraping: Argentina_1_Superliga (ARG)

# %%
teams_df = "../data/teams_trmk.csv"

scrape_team_data(teams_df)
# Out:
# flamengo-rio-de-janeiro
# se-palmeiras-sao-paulo
# gremio-foot-ball-porto-alegrense
# corinthians-sao-paulo
# sc-internacional-porto-alegre
# atletico-mineiro
# fc-sao-paulo
# fc-santos
# fluminense-football-club
# clube-atletico-paranaense
# vasco-da-gama-rio-de-janeiro
# clube-atletico-bragantino-sp-
# ec-bahia
# botafogo-fr-rio-de-janeiro
# goias-esporte-clube
# coritiba-fc
# fortaleza-esporte-clube
# ceara-sporting-club-ce-
# sport-club-do-recife
# atletico-goianiense
# los-angeles-football-club
# atlanta-united-fc
# inter-miami-cf
# new-york-city-fc
# toronto-fc
# los-angeles-galaxy
# seattle-sounders-fc
# columbus-crew
# sporting-kansas-city
# fc-dallas
# portland-timbers
# minnesota-united-fc
# d-c-united
# fc-cincinnati
# chicago-fire
# orlando-city-sc
# colorado-rapids
# new-england-revolution
# houston-dynamo
# new-york-red-bulls
# philadelphia-union
# montreal-impact
# vancouver-whitecaps
# nashville-mls-team
# san-jose-earthquakes
# real-salt-lake-city
# cf-monterrey
# cf-america
# tigres-uanl
# cd-cruz-azul
# cf-pachuca
# deportivo-guadalajara
# santos-laguna
# atlas-guadalajara
# club-tijuana
# unam-pumas
# club-leon-fc
# puebla-fc
# queretaro-fc
# deportivo-toluca
# monarcas-morelia
# club-necaxa
# fc-juarez
# atletico-san-luis
# club-atletico-river-plate
# club-atletico-boca-juniors
# ca-independiente-de-avellaneda
# club-atletico-san-lorenzo-de-almagro
# racing-club-de-avellaneda
# club-atletico-velez-sarsfield
# club-atletico-lanus
# defensa-y-justicia
# estudiantes-de-la-plata
# club-atletico-colon-santa-fe-
# talleres-de-cordoba-ca
# club-atletico-rosario-central
# club-deportivo-godoy-cruz
# club-de-gimnasia-y-esgrima-la-plata
# club-atletico-banfield
# club-atletico-newells-old-boys
# club-atletico-huracan
# ca-union-santa-fe
# argentinos-juniors
# club-atletico-tucuman
# club-atletico-aldosivi-mdp-
# club-atletico-central-cordoba-sde-
# club-atletico-patronato
# arsenal-de-sarandi-fc
# C:\Users\joaog\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
# players_df = pd.read_csv("../data/players_trmk.csv")
# fix_heights(players_df)

# %% [markdown]
# ## Save scraped data on SQL Database

# %%
from sqlalchemy import *
from sqlalchemy.schema import *
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.sql import text
import contextlib 
import json

# %%
rds_connection_string = "postgres:PostgreSQL@localhost:5432/trfmk_scrape_db"
engine = create_engine(f'postgresql://{rds_connection_string}')
metadata = MetaData()

# %%
leagues_df = pd.read_csv("../data/leagues_data.csv")
teams_df = pd.read_csv("../data/teams_trmk.csv")
players_df = pd.read_csv("../data/players_trmk.csv")

# %%
engine.execute(DropSchema('public', cascade = True))
engine.execute('CREATE SCHEMA IF NOT EXISTS public;')

players_df.to_sql(name = 'players',index_label= None, index= False, con=engine, if_exists='replace')
teams_df.to_sql(name = 'teams', index_label= None, index= False, con=engine, if_exists='replace')
leagues_df.to_sql(name = 'leagues', index_label= None, index= False, con=engine, if_exists='replace')

with engine.connect() as con:
    con.execute('ALTER TABLE leagues ADD CONSTRAINT pk_Leagues PRIMARY KEY ("league_ID")')
    con.execute('ALTER TABLE teams ADD CONSTRAINT pk_Teams PRIMARY KEY ("team_ID")')
    con.execute('ALTER TABLE players ADD CONSTRAINT pk_Players PRIMARY KEY ("players_ID")')
    con.execute('ALTER TABLE Teams ADD CONSTRAINT fk_Teams_league_ID FOREIGN KEY("league_ID") REFERENCES Leagues ("league_ID");')
    con.execute('ALTER TABLE Players ADD CONSTRAINT fk_Players_team_ID FOREIGN KEY("team_ID") REFERENCES Teams ("team_ID");')

# %%
# read database
pd.read_sql_query('SELECT * FROM  leagues JOIN (teams JOIN players USING("team_ID")) USING ("league_ID")', con=engine)
# Out:
#       league_ID    country  tier      league_name  \
# 0             1     Brazil     1   Brazil Serie A
# 1             1     Brazil     1   Brazil Serie A
# 2             1     Brazil     1   Brazil Serie A
# 3             1     Brazil     1   Brazil Serie A
# 4             1     Brazil     1   Brazil Serie A
# ...         ...        ...   ...              ...
# 2964          4  Argentina     1  Superliga (ARG)
# 2965          4  Argentina     1  Superliga (ARG)
# 2966          4  Argentina     1  Superliga (ARG)
# 2967          4  Argentina     1  Superliga (ARG)
# 2968          4  Argentina     1  Superliga (ARG)
#
#                                             league_link  team_ID  \
# 0     https://www.transfermarkt.com/campeonato-brasi...        1
# 1     https://www.transfermarkt.com/campeonato-brasi...        1
# 2     https://www.transfermarkt.com/campeonato-brasi...        1
# 3     https://www.transfermarkt.com/campeonato-brasi...        1
# 4     https://www.transfermarkt.com/campeonato-brasi...        1
# ...                                                 ...      ...
# 2964  https://www.transfermarkt.com/primera-division...       88
# 2965  https://www.transfermarkt.com/primera-division...       88
# 2966  https://www.transfermarkt.com/primera-division...       88
# 2967  https://www.transfermarkt.com/primera-division...       88
# 2968  https://www.transfermarkt.com/primera-division...       88
#
#                               club  squad  foreigners  avg_market_value_m  \
# 0     Clube de Regatas do Flamengo     29           3                4.81
# 1     Clube de Regatas do Flamengo     29           3                4.81
# 2     Clube de Regatas do Flamengo     29           3                4.81
# 3     Clube de Regatas do Flamengo     29           3                4.81
# 4     Clube de Regatas do Flamengo     29           3                4.81
# ...                            ...    ...         ...                 ...
# 2964           Arsenal Futbol Club     29           2                0.29
# 2965           Arsenal Futbol Club     29           2                0.29
# 2966           Arsenal Futbol Club     29           2                0.29
# 2967           Arsenal Futbol Club     29           2                0.29
# 2968           Arsenal Futbol Club     29           2                0.29
#
#       ...  field_position Age        Nat  Height   foot   dt_joined  \
# 0     ...             GLK  35     Brazil    1.87   left  2017-07-16
# 1     ...             GLK  21     Brazil    1.96   both  2019-08-31
# 2     ...             GLK  28     Brazil    1.94  right  2013-01-01
# 3     ...             GLK  22     Brazil    1.88  right  2017-01-01
# 4     ...             DEF  27     Brazil    1.83  right  2019-01-01
# ...   ...             ...  ..        ...     ...    ...         ...
# 2964  ...             ATT  23  Argentina    1.95  right  2018-07-01
# 2965  ...             ATT  26  Argentina    1.83  right  2018-07-11
# 2966  ...             ATT  25  Argentina    1.78  right  2019-07-01
# 2967  ...             ATT  24    Uruguay    1.71  right  2020-01-21
# 2968  ...             ATT  32  Argentina     NaN      -  2018-07-04
#
#                                    prev_team  contract_expires market_value  \
# 0                                Valencia CF        2020-12-31         3.30
# 1           Clube de Regatas do Flamengo U20        2023-09-30         0.53
# 2           Clube de Regatas do Flamengo U20        2022-04-30         0.47
# 3           Clube de Regatas do Flamengo U20        2022-12-31         0.06
# 4                    Sao Paulo Futebol Clube        2023-12-31         5.66
# ...                                      ...               ...          ...
# 2964                  Arsenal Futbol Club II        2020-06-30         0.47
# 2965                  Club Atletico Banfield        2020-06-30         0.38
# 2966  Club Social y Atletico Guillermo Brown        2020-06-30         0.38
# 2967                Deportivo Villa Espanola        2021-06-30         0.24
# 2968                 Club Atletico Los Andes        2020-06-30         0.18
#
#                                             player_page
# 0     https://www.transfermarkt.com/diego-alves/prof...
# 1     https://www.transfermarkt.com/hugo-souza/profi...
# 2     https://www.transfermarkt.com/cesar/profil/spi...
# 3     https://www.transfermarkt.com/gabriel-batista/...
# 4     https://www.transfermarkt.com/rodrigo-caio/pro...
# ...                                                 ...
# 2964  https://www.transfermarkt.com/facundo-pons/pro...
# 2965  https://www.transfermarkt.com/juan-manuel-garc...
# 2966  https://www.transfermarkt.com/lautaro-parisi/p...
# 2967  https://www.transfermarkt.com/jhonatan-candia/...
# 2968  https://www.transfermarkt.com/ezequiel-cerica/...
#
# [2969 rows x 26 columns]

# %% [markdown]
# ### Save query as JSON file

# %%
pd.read_sql_query('SELECT * FROM  leagues JOIN (teams JOIN players USING("team_ID")) USING ("league_ID")', con=engine)\
.to_json(r'../dashboard/static/data/data.json', orient='records')

# %% [markdown]
# # TEST

# %%
teams_df.tail(50)
# Out:
#     team_ID  league_ID                                     club  squad  \
# 38       39          2                           Houston Dynamo     29
# 39       40          2                       New York Red Bulls     27
# 40       41          2                       Philadelphia Union     27
# 41       42          2                          Montreal Impact     29
# 42       43          2                   Vancouver Whitecaps FC     28
# 43       44          2                             Nashville SC     28
# 44       45          2                     San Jose Earthquakes     29
# 45       46          2                      Real Salt Lake City     31
# 46       47          3                             CF Monterrey     38
# 47       48          3                               CF America     40
# 48       49          3                              Tigres UANL     33
# 49       50          3                             CD Cruz Azul     35
# 50       51          3                               CF Pachuca     40
# 51       52          3                    Deportivo Guadalajara     42
# 52       53          3                            Santos Laguna     37
# 53       54          3                        Atlas Guadalajara     40
# 54       55          3                             Club Tijuana     41
# 55       56          3                               UNAM Pumas     47
# 56       57          3                             Club Leon FC     37
# 57       58          3                                Puebla FC     47
# 58       59          3                             Queretaro FC     42
# 59       60          3                         Deportivo Toluca     33
# 60       61          3                         Monarcas Morelia     40
# 61       62          3                              Club Necaxa     42
# 62       63          3                                FC Juarez     40
# 63       64          3                     Atletico de San Luis     36
# 64       65          4                Club Atletico River Plate     33
# 65       66          4               Club Atletico Boca Juniors     31
# 66       67          4              Club Atletico Independiente     33
# 67       68          4     Club Atletico San Lorenzo de Almagro     45
# 68       69          4                              Racing Club     35
# 69       70          4            Club Atletico Velez Sarsfield     33
# 70       71          4                      Club Atletico Lanus     33
# 71       72          4                       Defensa y Justicia     41
# 72       73          4             Club Estudiantes de La Plata     32
# 73       74          4                      Club Atletico Colon     40
# 74       75          4                   Club Atletico Talleres     33
# 75       76          4            Club Atletico Rosario Central     37
# 76       77          4  Club Deportivo Godoy Cruz Antonio Tomba     40
# 77       78          4      Club de Gimnasia y Esgrima La Plata     43
# 78       79          4                   Club Atletico Banfield     38
# 79       80          4          Club Atletico Newell's Old Boys     33
# 80       81          4                    Club Atletico Huracan     37
# 81       82          4                      Club Atletico Union     36
# 82       83          4   Asociacion Atletica Argentinos Juniors     35
# 83       84          4                    Club Atletico Tucuman     34
# 84       85          4                   Club Atletico Aldosivi     32
# 85       86          4      Club Atletico Central Cordoba (SdE)     36
# 86       87          4                  Club Atletico Patronato     35
# 87       88          4                      Arsenal Futbol Club     29
#
#     foreigners  avg_market_value_m  total_MV_m  \
# 38          21                0.92       26.73
# 39          13                0.98       26.41
# 40          15                0.97       26.08
# 41          17                0.90       26.00
# 42          14                0.92       25.82
# 43          12                0.69       19.23
# 44          13                0.66       19.09
# 45          16                0.60       18.64
# 46          14                2.88      109.27
# 47          18                2.54      101.30
# 48          13                2.76       90.98
# 49          14                2.19       76.94
# 50          17                1.72       68.95
# 51           0                1.42       59.29
# 52           9                1.46       54.04
# 53          15                1.26       50.66
# 54          19                1.19       49.03
# 55          10                0.98       45.90
# 56          14                1.18       43.48
# 57          16                0.86       40.65
# 58          15                0.96       40.30
# 59          12                1.14       37.70
# 60          16                0.83       33.16
# 61          15                0.67       28.30
# 62          16                0.65       26.02
# 63          15                0.72       25.96
# 64           6                4.59      151.51
# 65           8                3.71      114.73
# 66           7                2.65       87.61
# 67           5                1.72       77.74
# 68           6                1.78       62.36
# 69           5                1.83       60.27
# 70           4                1.66       54.93
# 71           6                1.12       46.11
# 72           6                1.43       45.70
# 73           7                1.06       42.57
# 74           7                1.24       40.75
# 75           6                1.01       37.38
# 76           8                0.81       32.57
# 77           8                0.74       31.72
# 78           6                0.83       31.39
# 79           2                0.85       28.00
# 80           5                0.68       25.25
# 81           5                0.67       24.31
# 82           5                0.62       21.57
# 83           3                0.63       21.39
# 84           5                0.59       18.74
# 85           5                0.40       14.51
# 86           3                0.37       12.80
# 87           2                0.29        8.47
#
#                                              Logo_img  \
# 38  https://tmssl.akamaized.net/images/wappen/head...
# 39  https://tmssl.akamaized.net/images/wappen/head...
# 40  https://tmssl.akamaized.net/images/wappen/head...
# 41  https://tmssl.akamaized.net/images/wappen/head...
# 42  https://tmssl.akamaized.net/images/wappen/head...
# 43  https://tmssl.akamaized.net/images/wappen/head...
# 44  https://tmssl.akamaized.net/images/wappen/head...
# 45  https://tmssl.akamaized.net/images/wappen/head...
# 46  https://tmssl.akamaized.net/images/wappen/head...
# 47  https://tmssl.akamaized.net/images/wappen/head...
# 48  https://tmssl.akamaized.net/images/wappen/head...
# 49  https://tmssl.akamaized.net/images/wappen/head...
# 50  https://tmssl.akamaized.net/images/wappen/head...
# 51  https://tmssl.akamaized.net/images/wappen/head...
# 52  https://tmssl.akamaized.net/images/wappen/head...
# 53  https://tmssl.akamaized.net/images/wappen/head...
# 54  https://tmssl.akamaized.net/images/wappen/head...
# 55  https://tmssl.akamaized.net/images/wappen/head...
# 56  https://tmssl.akamaized.net/images/wappen/head...
# 57  https://tmssl.akamaized.net/images/wappen/head...
# 58  https://tmssl.akamaized.net/images/wappen/head...
# 59  https://tmssl.akamaized.net/images/wappen/head...
# 60  https://tmssl.akamaized.net/images/wappen/head...
# 61  https://tmssl.akamaized.net/images/wappen/head...
# 62  https://tmssl.akamaized.net/images/wappen/head...
# 63  https://tmssl.akamaized.net/images/wappen/head...
# 64  https://tmssl.akamaized.net/images/wappen/head...
# 65  https://tmssl.akamaized.net/images/wappen/head...
# 66  https://tmssl.akamaized.net/images/wappen/head...
# 67  https://tmssl.akamaized.net/images/wappen/head...
# 68  https://tmssl.akamaized.net/images/wappen/head...
# 69  https://tmssl.akamaized.net/images/wappen/head...
# 70  https://tmssl.akamaized.net/images/wappen/head...
# 71  https://tmssl.akamaized.net/images/wappen/head...
# 72  https://tmssl.akamaized.net/images/wappen/head...
# 73  https://tmssl.akamaized.net/images/wappen/head...
# 74  https://tmssl.akamaized.net/images/wappen/head...
# 75  https://tmssl.akamaized.net/images/wappen/head...
# 76  https://tmssl.akamaized.net/images/wappen/head...
# 77  https://tmssl.akamaized.net/images/wappen/head...
# 78  https://tmssl.akamaized.net/images/wappen/head...
# 79  https://tmssl.akamaized.net/images/wappen/head...
# 80  https://tmssl.akamaized.net/images/wappen/head...
# 81  https://tmssl.akamaized.net/images/wappen/head...
# 82  https://tmssl.akamaized.net/images/wappen/head...
# 83  https://tmssl.akamaized.net/images/wappen/head...
# 84  https://tmssl.akamaized.net/images/wappen/head...
# 85  https://tmssl.akamaized.net/images/wappen/head...
# 86  https://tmssl.akamaized.net/images/wappen/head...
# 87  https://tmssl.akamaized.net/images/wappen/head...
#
#                                             link_page
# 38  https://www.transfermarkt.com/houston-dynamo/k...
# 39  https://www.transfermarkt.com/new-york-red-bul...
# 40  https://www.transfermarkt.com/philadelphia-uni...
# 41  https://www.transfermarkt.com/montreal-impact/...
# 42  https://www.transfermarkt.com/vancouver-whitec...
# 43  https://www.transfermarkt.com/nashville-mls-te...
# 44  https://www.transfermarkt.com/san-jose-earthqu...
# 45  https://www.transfermarkt.com/real-salt-lake-c...
# 46  https://www.transfermarkt.com/cf-monterrey/kad...
# 47  https://www.transfermarkt.com/cf-america/kader...
# 48  https://www.transfermarkt.com/tigres-uanl/kade...
# 49  https://www.transfermarkt.com/cd-cruz-azul/kad...
# 50  https://www.transfermarkt.com/cf-pachuca/kader...
# 51  https://www.transfermarkt.com/deportivo-guadal...
# 52  https://www.transfermarkt.com/santos-laguna/ka...
# 53  https://www.transfermarkt.com/atlas-guadalajar...
# 54  https://www.transfermarkt.com/club-tijuana/kad...
# 55  https://www.transfermarkt.com/unam-pumas/kader...
# 56  https://www.transfermarkt.com/club-leon-fc/kad...
# 57  https://www.transfermarkt.com/puebla-fc/kader/...
# 58  https://www.transfermarkt.com/queretaro-fc/kad...
# 59  https://www.transfermarkt.com/deportivo-toluca...
# 60  https://www.transfermarkt.com/monarcas-morelia...
# 61  https://www.transfermarkt.com/club-necaxa/kade...
# 62  https://www.transfermarkt.com/fc-juarez/kader/...
# 63  https://www.transfermarkt.com/atletico-san-lui...
# 64  https://www.transfermarkt.com/club-atletico-ri...
# 65  https://www.transfermarkt.com/club-atletico-bo...
# 66  https://www.transfermarkt.com/ca-independiente...
# 67  https://www.transfermarkt.com/club-atletico-sa...
# 68  https://www.transfermarkt.com/racing-club-de-a...
# 69  https://www.transfermarkt.com/club-atletico-ve...
# 70  https://www.transfermarkt.com/club-atletico-la...
# 71  https://www.transfermarkt.com/defensa-y-justic...
# 72  https://www.transfermarkt.com/estudiantes-de-l...
# 73  https://www.transfermarkt.com/club-atletico-co...
# 74  https://www.transfermarkt.com/talleres-de-cord...
# 75  https://www.transfermarkt.com/club-atletico-ro...
# 76  https://www.transfermarkt.com/club-deportivo-g...
# 77  https://www.transfermarkt.com/club-de-gimnasia...
# 78  https://www.transfermarkt.com/club-atletico-ba...
# 79  https://www.transfermarkt.com/club-atletico-ne...
# 80  https://www.transfermarkt.com/club-atletico-hu...
# 81  https://www.transfermarkt.com/ca-union-santa-f...
# 82  https://www.transfermarkt.com/argentinos-junio...
# 83  https://www.transfermarkt.com/club-atletico-tu...
# 84  https://www.transfermarkt.com/club-atletico-al...
# 85  https://www.transfermarkt.com/club-atletico-ce...
# 86  https://www.transfermarkt.com/club-atletico-pa...
# 87  https://www.transfermarkt.com/arsenal-de-saran...

# %%
teams_test = teams_df.iloc[[2, 38, 63, 64]]
teams_test
# Out:
#     team_ID  league_ID                              club  squad  foreigners  \
# 2         3          1  Gremio Foot-Ball Porto Alegrense     36           2
# 38       39          2                    Houston Dynamo     29          21
# 63       64          3              Atletico de San Luis     36          15
# 64       65          4         Club Atletico River Plate     33           6
#
#     avg_market_value_m  total_MV_m  \
# 2                 2.28       81.93
# 38                0.92       26.73
# 63                0.72       25.96
# 64                4.59      151.51
#
#                                              Logo_img  \
# 2   https://tmssl.akamaized.net/images/wappen/head...
# 38  https://tmssl.akamaized.net/images/wappen/head...
# 63  https://tmssl.akamaized.net/images/wappen/head...
# 64  https://tmssl.akamaized.net/images/wappen/head...
#
#                                             link_page
# 2   https://www.transfermarkt.com/gremio-foot-ball...
# 38  https://www.transfermarkt.com/houston-dynamo/k...
# 63  https://www.transfermarkt.com/atletico-san-lui...
# 64  https://www.transfermarkt.com/club-atletico-ri...

# %%
https://www.transfermarkt.com/club-atletico-river-plate/kader/verein/209/saison_id/2019/plus/1

# %%
https://www.transfermarkt.com/club-atletico-river-plate/kader/verein/209/saison_id/2019/plus/1

# %%
def scrape_test_data(teams_df):
    player_id = 1
    name = []
    player_page = []
    position = []
    f_posi = []
    Age = []
    Nat = []
    Height = []
    foot = []
    dt_joined = []
    prev_team = []
    contract_expires = []
    market_value = []
    team_ID = []
    players_ID = []
    

    df_league = teams_df
    for index, row in df_league.iterrows():
        team_id = row["team_ID"]
        team = row["link_page"]
        league_id = row["league_ID"]
        print(league_id)
        team_name = team.split('/')[-8]
        print(team_name)
        time.sleep(randint(1,2))
        html = requests.get(team, headers=headers)
        soup = BeautifulSoup(html.content, 'html.parser')
        htmltable = soup.find('table', class_= "items")

        results = htmltable.findAll("tr", class_ =["odd","even"])


        for result in results:
            features = result.findAll("td")

            name_1 = features[2].find("img", alt=True)["alt"]

            player_page.append("https://www.transfermarkt.com" + features[3].find("a", href=True)["href"])

            position_1 = features[4].text
            
            if position_1 in ("Centre-Back", "Left-Back", "Right-Back", "Defender"):
                field_posit = "DEF"
            elif position_1 in ("Defensive Midfield", "Central Midfield" , "Right Midfield" , "Left Midfield" , \
            "Attacking Midfield" , "Midfield"):
                field_posit = "MID"
            elif position_1 in ("Left Winger" , "Right Winger" , "Centre-Forward" , "Second Striker" , "Forward"):
                field_posit = "ATT"
            else:
                field_posit = "GLK"

            try:
                age_1 = int((features[5].text.split("(",)[-1])[:-1])
            except:
                age_1 = ""

            nat = features[6].img["alt"]
            
            if league_id == 3 or   league_id == 4:
                print("test1")
                try:
                    Height_1 = float((features[8].text.split(" ")[0]).replace(",", "."))
                except:
                    Height_1 = ""

                foot_1 = features[9].text
                dt_joined_1 = features[10].text
                try:
                    dt_joined_1 = datetime.strptime(dt_joined_1, '%b %d, %Y').date()
                except:
                    dt_joined_1 = ""
                try:
                    prev_team_1 = features[11].img["alt"]
                except:
                    prev_team_1 = "N.A."

                contract_expires_1 = features[12].text
                try:
                    contract_expires_1 = datetime.strptime(contract_expires_1, '%d.%m.%Y').date()
                except:
                    contract_expires_1 = ""

                try:
                    market_value_1 = get_value_us(features[13].text[:-2])
                except:
                    market_value_1 = 0
            else:
                print("test2")
                try:
                    Height_1 = float((features[7].text.split(" ")[0]).replace(",", "."))
                except:
                    Height_1 = ""

                foot_1 = features[8].text

                dt_joined_1 = features[9].text
                try:
                    dt_joined_1 = datetime.strptime(dt_joined_1, '%b %d, %Y').date()
                except:
                    dt_joined_1 = ""

                try:
                    prev_team_1 = features[10].img["alt"]
                except:
                    prev_team_1 = "N.A."


                contract_expires_1 = features[11].text
                try:
                    contract_expires_1 = datetime.strptime(contract_expires_1, '%d.%m.%Y').date()
                except:
                    contract_expires_1 = ""

                try:
                    market_value_1 = get_value_us(features[12].text[:-2])
                except:
                    market_value_1 = 0

            name.append(strip_accents(name_1))
            position.append(position_1)
            f_posi.append(field_posit)
            Age.append(age_1)
            Nat.append(nat)
            Height.append(Height_1)
            foot.append(foot_1)
            dt_joined.append(dt_joined_1)
            prev_team.append(strip_accents(prev_team_1))
            contract_expires.append(contract_expires_1)
            market_value.append(market_value_1)
            team_ID.append(team_id)
            players_ID.append(player_id)
            player_id = player_id+1

#         time.sleep(randint(3,5))
        
    df = pd.DataFrame(list(zip(players_ID, team_ID, name, position,f_posi, Age,Nat, Height, foot,dt_joined,prev_team, contract_expires,\
                               market_value,player_page)), 
                      columns =["players_ID", "team_ID","name","position","field_position", "Age", "Nat","Height","foot",'dt_joined',"prev_team", \
                                "contract_expires", "market_value","player_page" ])
    df['players_ID'] = df['players_ID'].astype(int)
    df['team_ID'] = df['team_ID'].astype(int)
    df['dt_joined'] = pd.to_datetime(df['dt_joined'])
    df['contract_expires'] = pd.to_datetime(df['contract_expires'])
    
    fix_heights(df)
    
    return df

# %%
scrape_test_data(teams_test)
# Out:
# 1
# gremio-foot-ball-porto-alegrense
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# 2
# houston-dynamo
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# test2
# 3
# atletico-san-luis
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# 4
# club-atletico-river-plate
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# test1
# C:\Users\joaog\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#      players_ID  team_ID              name        position field_position  \
# 0             1        3      Paulo Victor      Goalkeeper            GLK
# 1             2        3       Julio Cesar      Goalkeeper            GLK
# 2             3        3         Vanderlei      Goalkeeper            GLK
# 3             4        3            Brenno      Goalkeeper            GLK
# 4             5        3  Walter Kannemann     Centre-Back            DEF
# ..          ...      ...               ...             ...            ...
# 129         130       65     Matias Suarez  Centre-Forward            ATT
# 130         131       65      Lucas Pratto  Centre-Forward            ATT
# 131         132       65    Ignacio Scocco  Centre-Forward            ATT
# 132         133       65  Federico Girotti  Centre-Forward            ATT
# 133         134       65     Lucas Beltran  Centre-Forward            ATT
#
#      Age        Nat Height   foot  dt_joined  \
# 0     33     Brazil   1.87   left 2017-07-13
# 1     34     Brazil   1.91  right 2019-01-03
# 2     36     Brazil   1.95  right 2020-01-18
# 3     21     Brazil    1.9  right 2019-01-01
# 4     29  Argentina   1.84   left 2016-07-15
# ..   ...        ...    ...    ...        ...
# 129   31  Argentina   1.83   both 2019-01-26
# 130   31  Argentina   1.88  right 2018-01-08
# 131   34  Argentina   1.76  right 2017-07-01
# 132   20  Argentina             - 2020-01-01
# 133   18  Argentina   1.76  right 2020-01-01
#
#                               prev_team contract_expires  market_value  \
# 0          Clube de Regatas do Flamengo       2022-12-31          1.42
# 1              Fluminense Football Club       2020-12-31          0.94
# 2                             Santos FC       2021-12-31          0.94
# 3    Gremio Foot-Ball Porto Alegrense B       2021-12-31          0.06
# 4                     Atlas Guadalajara       2022-12-31          5.66
# ..                                  ...              ...           ...
# 129              Club Atletico Belgrano       2022-06-30          3.30
# 130             Sao Paulo Futebol Clube       2022-06-30          2.83
# 131     Club Atletico Newell's Old Boys       2020-06-30          1.42
# 132        Club Atletico River Plate II       2022-12-31          0.00
# 133        Club Atletico River Plate II       2021-06-30          0.00
#
#                                            player_page
# 0    https://www.transfermarkt.com/paulo-victor/pro...
# 1    https://www.transfermarkt.com/julio-cesar/prof...
# 2    https://www.transfermarkt.com/vanderlei/profil...
# 3    https://www.transfermarkt.com/brenno/profil/sp...
# 4    https://www.transfermarkt.com/walter-kannemann...
# ..                                                 ...
# 129  https://www.transfermarkt.com/matias-suarez/pr...
# 130  https://www.transfermarkt.com/lucas-pratto/pro...
# 131  https://www.transfermarkt.com/ignacio-scocco/p...
# 132  https://www.transfermarkt.com/federico-girotti...
# 133  https://www.transfermarkt.com/lucas-beltran/pr...
#
# [134 rows x 14 columns]
